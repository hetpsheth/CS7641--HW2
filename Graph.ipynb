# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Full_NN.csv')

# %%
df.head()
df.columns
# Out:
# Index(['Iteration', 'BACKPROP_train', 'RHC_train', 'SA0.15_train',
#        'SA0.35_train', 'SA0.55_train', 'SA0.7_train', 'SA0.95_train',
#        'GA_50_20_20_train', 'GA_50_20_10_train', 'GA_50_10_20_train',
#        'GA_50_10_10_train', 'BACKPROP_test', 'RHC_test', 'SA0.15_test',
#        'SA0.35_test', 'SA0.55_test', 'SA0.7_test', 'SA0.95_test',
#        'GA_50_20_20_test', 'GA_50_20_10_test', 'GA_50_10_20_test',
#        'GA_50_10_10_test', 'BACKPROP_time', 'RHC_time', 'SA0.15_time',
#        'SA0.35_time', 'SA0.55_time', 'SA0.7_time', 'SA0.95_time',
#        'GA_50_20_20_time', 'GA_50_20_10_time', 'GA_50_10_20_time',
#        'GA_50_10_10_time'],
#       dtype='object')

# %%
plt.plot(df['Iteration'], df['RHC_train'], color='g')
# plt.plot(df['Iteration'], df['RHC_test'], color='r')
# plt.plot(year, pop_india, color='orange')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuracy')
plt.title('NN- RHC Train Accuracy')
plt.show()

# %%
# plt.plot(df['Iteration'], df['RHC_train'], color='g')
plt.plot(df['Iteration'], df['RHC_test'], color='r')
# plt.plot(year, pop_india, color='orange')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuracy')
plt.title('NN- RHC Test Accuracy')
plt.show()

# %%
# plt.plot(df['Iteration'], df['RHC_train'], color='g')
plt.plot(df['Iteration'], df['RHC_time'], color='r')
plt.xlabel('Number of Iterations')
plt.ylabel('Time')
plt.title('NN- RHC Time taken')
plt.show()

# %%
plt.plot(df['Iteration'], df['SA0.15_train'], color='r', label='0.15')
plt.plot(df['Iteration'], df['SA0.35_train'], color='g', label='0.35')
plt.plot(df['Iteration'], df['SA0.55_train'], color='b', label='0.55')
plt.plot(df['Iteration'], df['SA0.7_train'], color='orange', label='0.7')
plt.plot(df['Iteration'], df['SA0.95_train'], color='cyan', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuray')
plt.legend()
plt.title('NN- SA Train Accuracy')
plt.show()

# %%
plt.plot(df['Iteration'], df['SA0.15_test'], color='r', label='0.15')
plt.plot(df['Iteration'], df['SA0.35_test'], color='g', label='0.35')
plt.plot(df['Iteration'], df['SA0.55_test'], color='b', label='0.55')
plt.plot(df['Iteration'], df['SA0.7_test'], color='orange', label='0.7')
plt.plot(df['Iteration'], df['SA0.95_test'], color='cyan', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuray')
plt.legend()
plt.title('NN- SA Test Accuracy')
plt.show()

# %%
plt.plot(df['Iteration'], df['SA0.15_time'], color='r', label='0.15')
plt.plot(df['Iteration'], df['SA0.35_time'], color='g', label='0.35')
plt.plot(df['Iteration'], df['SA0.55_time'], color='b', label='0.55')
plt.plot(df['Iteration'], df['SA0.7_time'], color='orange', label='0.7')
plt.plot(df['Iteration'], df['SA0.95_time'], color='cyan', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Training Time')
plt.legend()
plt.title('NN- SA Time')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(df['Iteration'], df['GA_50_10_10_train'], color='r', label='(50,10,10)')
plt.plot(df['Iteration'], df['GA_50_10_20_train'], color='g', label='(50,10,20)')
plt.plot(df['Iteration'], df['GA_50_20_10_train'], color='b', label='(50,20,10)')
plt.plot(df['Iteration'], df['GA_50_20_20_train'], color='orange', label='(50,20,20)')
# plt.plot(df['Iteration'], df['SA0.95_time'], color='cyan', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.title('NN- GA Train Accuracy')
plt.show()

# %%
plt.figure(figsize= (10, 5))
plt.plot(df['Iteration'], df['GA_50_10_10_test'], color='r', label='(50,10,10)')
plt.plot(df['Iteration'], df['GA_50_10_20_test'], color='g', label='(50,10,20)')
plt.plot(df['Iteration'], df['GA_50_20_10_test'], color='b', label='(50,20,10)')
plt.plot(df['Iteration'], df['GA_50_20_20_test'], color='orange', label='(50,20,20)')
# plt.plot(df['Iteration'], df['SA0.95_time'], color='cyan', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.title('NN- GA Test Accuracy')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(df['Iteration'], df['GA_50_10_10_time'], color='r', label='(50,10,10)')
plt.plot(df['Iteration'], df['GA_50_10_20_time'], color='g', label='(50,10,20)')
plt.plot(df['Iteration'], df['GA_50_20_10_time'], color='b', label='(50,20,10)')
plt.plot(df['Iteration'], df['GA_50_20_20_time'], color='orange', label='(50,20,20)')
# plt.plot(df['Iteration'], df['SA0.95_time'], color='cyan', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Time')
plt.legend()
plt.title('NN- GA Training Time')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(df['Iteration'], df['RHC_train'], color='r', label='RHC')
plt.plot(df['Iteration'], df['SA0.35_train'], color='g', label='SA')
plt.plot(df['Iteration'], df['GA_50_10_10_train'], color='b', label='GA')
plt.plot(df['Iteration'], df['BACKPROP_train'], color='orange', label='Backpropogation')
# plt.plot(df['Iteration'], df['GA_50_20_20_time'], color='orange', label='(50,20,20)')
# plt.plot(df['Iteration'], df['SA0.95_time'], color='cyan', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.title('NN- Train Accuracy')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(df['Iteration'], df['RHC_test'], color='r', label='RHC')
plt.plot(df['Iteration'], df['SA0.35_test'], color='g', label='SA')
plt.plot(df['Iteration'], df['GA_50_10_10_test'], color='b', label='GA')
plt.plot(df['Iteration'], df['BACKPROP_test'], color='orange', label='Backpropogation')
# plt.plot(df['Iteration'], df['GA_50_20_20_time'], color='orange', label='(50,20,20)')
# plt.plot(df['Iteration'], df['SA0.95_time'], color='cyan', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.title('NN- Test Accuracy')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(df['Iteration'], df['RHC_time'], color='r', label='RHC')
plt.plot(df['Iteration'], df['SA0.35_time'], color='g', label='SA')
plt.plot(df['Iteration'], df['GA_50_10_10_time'], color='b', label='GA')
plt.plot(df['Iteration'], df['BACKPROP_time'], color='orange', label='Backpropogation')
# plt.plot(df['Iteration'], df['GA_50_20_20_time'], color='orange', label='(50,20,20)')
# plt.plot(df['Iteration'], df['SA0.95_time'], color='cyan', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Time')
plt.legend()
plt.title('NN- Training Time')
plt.show()

# %% [markdown]
# <h1>TSP</h1>

# %%
tsp= pd.read_csv('Full_TSP.csv')

# %%
tsp.columns
# Out:
# Index(['Unnamed: 0', 'iterations', 'SA 0.15 fitness', 'SA 0.15 time',
#        'SA 0.15 feval', 'SA 0.35 fitness', 'SA 0.35 time', 'SA 0.35 feval',
#        'SA 0.55 fitness', 'SA 0.55 time', 'SA 0.55 feval', 'SA 0.75 fitness',
#        'SA 0.75 time', 'SA 0.75 feval', 'SA 0.95 fitness', 'SA 0.95 time',
#        'SA 0.95 feval', 'SA fitness', 'SA time', 'RHC fitness', 'RHC time',
#        'RHC feval', 'GA (100,50,50) fitness', 'GA (100,50,50) time',
#        'GA (100,50,50) feval', 'GA (100,50,30) fitness', 'GA (100,50,30) time',
#        'GA (100,50,30) feval', 'GA (100,50,10) fitness', 'GA (100,50,10) time',
#        'GA (100,50,10) feval', 'GA (100,30,50) fitness', 'GA (100,30,50) time',
#        'GA (100,30,50) feval', 'GA (100,30,30) fitness', 'GA (100,30,30) time',
#        'GA (100,30,30) feval', 'GA (100,30,10) fitness', 'GA (100,30,10) time',
#        'GA (100,30,10) feval', 'GA (100,10,50) fitness', 'GA (100,10,50) time',
# ...

# %%
# plt.figure(figsize= (10, 5))
plt.plot(tsp['iterations'], tsp['RHC fitness'], color='r', label='RHC')
plt.plot(tsp['iterations'], tsp['SA fitness'], color='g', label='SA')
plt.plot(tsp['iterations'], tsp['GA fitness'], color='b', label='GA')
plt.plot(tsp['iterations'], tsp['MIMIC fitness'], color='orange', label='MIMIC')
plt.xlabel('Number of Iterations')
plt.ylabel('Fitness')
plt.legend()
plt.title('TSP- Fitness')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(tsp['iterations'], tsp['RHC time'], color='r', label='RHC')
plt.plot(tsp['iterations'], tsp['SA time'], color='g', label='SA')
plt.plot(tsp['iterations'], tsp['GA time'], color='b', label='GA')
plt.plot(tsp['iterations'], tsp['MIMIC time'], color='orange', label='MIMIC')
plt.xlabel('Number of Iterations')
plt.ylabel('Time')
plt.legend()
plt.title('TSP- Time')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(tsp['iterations'], tsp['GA (100,10,10) fitness'], color='r', label='(100,10,10)')
plt.plot(tsp['iterations'], tsp['GA (100,10,30) fitness'], color='g', label='(100,10,30)')
plt.plot(tsp['iterations'], tsp['GA (100,30,50) fitness'], color='b', label='(100,30,50)')
plt.plot(tsp['iterations'], tsp['GA (100,50,50) fitness'], color='orange', label='(100,50,50)')
plt.xlabel('Number of Iterations')
plt.ylabel('Fitness')
plt.legend()
plt.title('TSP GA- Fitness')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(tsp['iterations'], tsp['SA 0.15 fitness'], color='r', label='0.15')
plt.plot(tsp['iterations'], tsp['SA 0.35 fitness'], color='g', label='0.35')
plt.plot(tsp['iterations'], tsp['SA 0.55 fitness'], color='b', label='0.55')
plt.plot(tsp['iterations'], tsp['SA 0.75 fitness'], color='cyan', label='0.75')
plt.plot(tsp['iterations'], tsp['SA 0.95 fitness'], color='orange', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Fitness')
plt.legend()
plt.title('TSP SA- Fitness')
plt.show()

# %%
ff= pd.read_csv('Full_FLIPFLOP.csv')

# %%
ff.columns
# Out:
# Index(['Unnamed: 0', 'iterations', 'SA 0.15 fitness', 'SA 0.15 time',
#        'SA 0.15 feval', 'SA 0.35 fitness', 'SA 0.35 time', 'SA 0.35 feval',
#        'SA 0.55 fitness', 'SA 0.55 time', 'SA 0.55 feval', 'SA 0.75 fitness',
#        'SA 0.75 time', 'SA 0.75 feval', 'SA 0.95 fitness', 'SA 0.95 time',
#        'SA 0.95 feval', 'SA fitness', 'SA time', 'RHC fitness', 'RHC time',
#        'RHC feval', 'GA (100,50,50) fitness', 'GA (100,50,50) time',
#        'GA (100,50,50) feval', 'GA (100,50,30) fitness', 'GA (100,50,30) time',
#        'GA (100,50,30) feval', 'GA (100,50,10) fitness', 'GA (100,50,10) time',
#        'GA (100,50,10) feval', 'GA (100,30,50) fitness', 'GA (100,30,50) time',
#        'GA (100,30,50) feval', 'GA (100,30,30) fitness', 'GA (100,30,30) time',
#        'GA (100,30,30) feval', 'GA (100,30,10) fitness', 'GA (100,30,10) time',
#        'GA (100,30,10) feval', 'GA (100,10,50) fitness', 'GA (100,10,50) time',
# ...

# %%
# plt.figure(figsize= (10, 5))
plt.plot(ff['iterations'], ff['RHC fitness'], color='r', label='RHC')
plt.plot(ff['iterations'], ff['SA fitness'], color='g', label='SA')
plt.plot(ff['iterations'], ff['GA fitness'], color='b', label='GA')
plt.plot(ff['iterations'], ff['MIMIC fitness'], color='orange', label='MIMIC')
plt.xlabel('Number of Iterations')
plt.ylabel('Fitness')
plt.legend()
plt.title('FF- Fitness')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(ff['iterations'], ff['RHC time'], color='r', label='RHC')
plt.plot(ff['iterations'], ff['SA time'], color='g', label='SA')
plt.plot(ff['iterations'], ff['GA time'], color='b', label='GA')
plt.plot(ff['iterations'], ff['MIMIC time'], color='orange', label='MIMIC')
plt.xlabel('Number of Iterations')
plt.ylabel('Time')
plt.legend()
plt.title('FF- Time')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(ff['iterations'], ff['MIMIC (100,50,0.1) fitness'], color='r', label='(100,50,0.1)')
plt.plot(ff['iterations'], ff['MIMIC (100,50,0.3) fitness'], color='g', label='(100,50,0.3)')
plt.plot(ff['iterations'], ff['MIMIC (100,50,0.5) fitness'], color='b', label='(100,50,0.5)')
plt.plot(ff['iterations'], ff['MIMIC (100,50,0.7) fitness'], color='cyan', label='(100,50,0.7)')
plt.plot(ff['iterations'], ff['MIMIC (100,50,0.9) fitness'], color='orange', label='(100,50,0.9)')
plt.xlabel('Number of Iterations')
plt.ylabel('Fitness')
plt.legend()
plt.title('FF- MIMIC- Fitness')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(ff['iterations'], ff['SA 0.15 fitness'], color='r', label='0.15')
plt.plot(ff['iterations'], ff['SA 0.35 fitness'], color='g', label='0.35')
plt.plot(ff['iterations'], ff['SA 0.55 fitness'], color='b', label='0.55')
plt.plot(ff['iterations'], ff['SA 0.75 fitness'], color='cyan', label='0.75')
plt.plot(ff['iterations'], ff['SA 0.95 fitness'], color='orange', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Fitness')
plt.legend()
plt.title('FF- SA- Fitness')
plt.show()

# %%
cp= pd.read_csv('Full_CONTPEAKS.csv')

# %%
cp.columns
# Out:
# Index(['Unnamed: 0', 'iterations', 'SA 0.15 fitness', 'SA 0.15 time',
#        'SA 0.15 feval', 'SA 0.35 fitness', 'SA 0.35 time', 'SA 0.35 feval',
#        'SA 0.55 fitness', 'SA 0.55 time', 'SA 0.55 feval', 'SA 0.75 fitness',
#        'SA 0.75 time', 'SA 0.75 feval', 'SA 0.95 fitness', 'SA 0.95 time',
#        'SA 0.95 feval', 'SA fitness', 'SA time', 'RHC fitness', 'RHC time',
#        'RHC feval', 'GA (100,50,50) fitness', 'GA (100,50,50) time',
#        'GA (100,50,50) feval', 'GA (100,50,30) fitness', 'GA (100,50,30) time',
#        'GA (100,50,30) feval', 'GA (100,50,10) fitness', 'GA (100,50,10) time',
#        'GA (100,50,10) feval', 'GA (100,30,50) fitness', 'GA (100,30,50) time',
#        'GA (100,30,50) feval', 'GA (100,30,30) fitness', 'GA (100,30,30) time',
#        'GA (100,30,30) feval', 'GA (100,30,10) fitness', 'GA (100,30,10) time',
#        'GA (100,30,10) feval', 'GA (100,10,50) fitness', 'GA (100,10,50) time',
# ...

# %%
# plt.figure(figsize= (10, 5))
plt.plot(cp['iterations'], cp['RHC fitness'], color='r', label='RHC')
plt.plot(cp['iterations'], cp['SA fitness'], color='g', label='SA')
plt.plot(cp['iterations'], cp['GA fitness'], color='b', label='GA')
plt.plot(cp['iterations'], cp['MIMIC fitness'], color='orange', label='MIMIC')
plt.xlabel('Number of Iterations')
plt.ylabel('Fitness')
plt.legend()
plt.title('CP- Fitness')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(cp['iterations'], cp['RHC time'], color='r', label='RHC')
plt.plot(cp['iterations'], cp['SA time'], color='g', label='SA')
plt.plot(cp['iterations'], cp['GA time'], color='b', label='GA')
plt.plot(cp['iterations'], cp['MIMIC time'], color='orange', label='MIMIC')
plt.xlabel('Number of Iterations')
plt.ylabel('Time')
plt.legend()
plt.title('CP- Time')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(cp['iterations'], cp['SA 0.15 fitness'], color='r', label='0.15')
plt.plot(cp['iterations'], cp['SA 0.35 fitness'], color='g', label='0.35')
plt.plot(cp['iterations'], cp['SA 0.55 fitness'], color='b', label='0.55')
plt.plot(cp['iterations'], cp['SA 0.75 fitness'], color='cyan', label='0.75')
plt.plot(cp['iterations'], cp['SA 0.95 fitness'], color='orange', label='0.95')
plt.xlabel('Number of Iterations')
plt.ylabel('Fitness')
plt.legend()
plt.title('CP- SA- Fitness')
plt.show()

# %%
# plt.figure(figsize= (10, 5))
plt.plot(cp['iterations'], cp['GA (100,10,10) fitness'], color='r', label='(100,10,10)')
plt.plot(cp['iterations'], cp['GA (100,10,30) fitness'], color='g', label='(100,10,30)')
plt.plot(cp['iterations'], cp['GA (100,30,50) fitness'], color='b', label='(100,30,50)')
plt.plot(cp['iterations'], cp['GA (100,50,50) fitness'], color='orange', label='(100,50,50)')
plt.xlabel('Number of Iterations')
plt.ylabel('Fitness')
plt.legend()
plt.title('CP GA- Fitness')
plt.show()
